# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# 한글 폰트 문제 해결
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system... sorry~~~~')

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
iris_datasets = sns.load_dataset('iris')
titanic_datasets = sns.load_dataset('titanic')
tips_datasets = sns.load_dataset('tips')
flights_datasets = sns.load_dataset('flights')

# %%
titanic_datasets.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.6+ KB

# %%
titanic_datasets.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %% [markdown]
# - barplot() : 카테고리값에 따른 숫자값의 평균과 편차를 표시하는 차트
# - 평균은 막대의 높이, 편차 에러바

# %%
# darkgrid, whitegrid, dark, white,
sns.set_style('dark')

fig = plt.figure(figsize = (15,5))
area01 = fig.add.subplot(1, 3, 1)
area01 = fig.add.subplot(1, 3, 2)
area01 = fig.add.subplot(1, 3, 3)


# 성별에 따른 생존를

plt.show()
plt.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-16-256cc762cdc6> in <module>
#       3
#       4 fig = plt.figure(figsize = (15,5))
# ----> 5 area01 = fig.add.subplot(1, 3, 1)
#       6 area01 = fig.add.subplot(1, 3, 2)
#       7 area01 = fig.add.subplot(1, 3, 3)
#
# AttributeError: 'Figure' object has no attribute 'add'

# %%
sns.pairplot(iris_datasets)
