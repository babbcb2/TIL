# %% [markdown]
# ### 학습목표
# - 왜 크롤링이 필요한지?
# - 페이지 처리하는 방법
# - json scraping

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
from urllib.error import HTTPError
from urllib.error import URLError

#
from selenium import webdriver
import time

# %%
path = './driver/Chromedriver.exe'
driver = webdriver.Chrome(path)
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="485a97fdf9a7e9d78b44f5a3c33efd80")>

# %%
driver.get('https://python.org')

# %% [markdown]
# - find_element_*()
# - find_elements_*()
#
# - find_element_by_id()
# - find_element_by_name()
# - find_element_by_css_selector()
# - find_element_by_tag_name()

# %%
menus = driver.find_elements_by_css_selector('#top ul.menu li')
# menus[2].text

# %%
clickMenu = None

for li in menus :
    if li.text == 'Docs' :
        clickMenu = li

clickMenu.click()
time.sleep(5)
driver.close()

# %%
# naver 쇼핑인사이트
driver.get('https://datalab.naver.com/shoppingInsight/sCategory.naver')

# %%
ul_tag = driver.find_element_by_css_selector('.rank_top1000_list')
ul_tag
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="78ee6e92-c38b-432d-a33d-71712e9228a5")>

# %%
li_tag = ul_tag.find_elements_by_tag_name ('li')
len(li_tag)
# Out:
# 20

# %%
li_tag[0].text
# Out:
# '1\n트위드자켓'

# %%
for li in li_tag :
    print(li.text.split('\n')[1])
# Out:
# 트위드자켓
# 원피스
# 트렌치코트
# 여성경량패딩
# 나이키바람막이
# 블라우스
# 쥬시쥬디
# 여성트레이닝세트
# 후드집업
# 써스데이아일랜드원피스
# 핸드메이드코트
# 반팔티
# 잠옷
# 바람막이
# 맨투맨
# 롱원피스
# 나이키맨투맨
# 여성자켓
# 남자경량패딩
# 여성가디건

# %%
# [실습] 자동차 제조사 전체페이지 클릭

driver.get('https://auto.naver.com/car/mainList.nhn')

# %%
carelenentBtn = driver.find_element_by_css_selector('#container > div.spot_main > div.spot_aside > div.tit > a')
carelenentBtn.click()

# %%
time.sleep(3)

# %%
# attrs (src) - BS
# get_attribute('src')
# get_attribute('href')

# %%
makers = driver.find_elements_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.emblem_area > ul > li')
makers
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="a4784d54-845a-4f5e-a582-60edae719f23")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="ff2862a4-c250-46a6-b320-6b5567176f31")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="e4d1dffe-87a1-42b0-b670-50df3bf3d35a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8cfd0059-64c4-491c-8e40-50f0837c64f1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="27c8137d-2d40-4709-85e8-61e37d801aa5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="d46d130d-681e-4644-b880-65f5eb7b6078")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="e9f0c2f6-e5e1-4331-b35f-0c139b1a3190")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="735d7b54-f21f-4b0f-9150-49991ddd244f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="f76a0f04-c951-4271-93c9-88e6bdf52613")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="913cd94a-de54-4940-8d51-32e43bfaf843")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="14341074-3f0f-4525-93e9-10eed5881e43")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7772f3d9-de7b-441a-bc6f-9836450b112f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="834aa637-126d-4658-82e9-ad0cd294d65f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="883e5213-41df-48f8-bdd5-a3463a8d15ee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="54bb1e8b-853a-4d92-b9cc-4b2c9b8f57b7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="6395cca6-df09-477d-b048-e6e91b967e2e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="d974b284-5713-4a56-bdb9-04fa54066e46")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="14675e65-eb41-46a0-9004-4854cb772e6a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="81773038-8c13-43af-9a05-249d2bcabea8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7e4d8660-d2ac-41f2-991e-e76633a28e5c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="07776d74-4497-4021-a501-51708e95b1ea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="ba9a9f3c-5d04-42f6-ba7f-c4de3a0bf525")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3fd3894b-05c0-4717-b4ad-5f1b96f6cdd0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="41b2f98f-2ad7-405b-be54-94a55d24b9c8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3518f545-9fc3-4e62-a6e2-f122a0154d5e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="a0492dde-f014-4fc8-8633-e94bad52db38")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="5ebc0dec-8168-490a-9f49-a6905776fbee")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="9c7e51c0-8b74-4090-94ac-e6349b182222")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="348a9dfb-ac73-42c5-9dfa-2bbbaf540f41")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="24443856-609d-49e2-9110-47b95a646fe4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="861da56d-02d7-4343-9ee0-bc2fa6793a59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="59f6e3a9-c076-4099-8d5f-e78ab7b9eaad")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="5af3b6b6-19c0-479b-9806-8cd89a229b48")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8c8786b4-cd7a-4880-b227-750029659929")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="e547db92-61aa-4ad9-bd9f-0add368d4bd6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="2dc9fefe-2d8f-4d68-9e7a-4fd181f93cbf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="0c427f31-8457-439a-a2cd-689f8e4de4f8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3332bdc2-16f2-4d18-aed8-8fadf16af235")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="f9fa3ec8-5d75-4983-879b-bf8f2c3e5041")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="b8a7d90f-9ae3-484f-af2b-39c207b7bb5b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="828d4c06-4406-4b0c-985e-1f92c8efc90f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="314bc449-1d53-4393-b55f-f145b983056c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="e28619f1-025b-4f44-87fe-fcc16c849d54")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="d4f4fded-74c4-4927-81de-f36ce175316e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="5108fdcd-b84e-4f7f-b99a-0ca5bdded81b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="986de4e0-5f08-4863-b901-eedc01b75572")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="9684cb09-3d8d-4143-9afe-525d818e877e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="e025f194-aee8-4ee1-afe9-cc353b0f0d93")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="d8d793d3-414c-4dff-95c3-4a81f54e8438")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3bbdde5f-7463-4247-9ebc-e8367a97d4cf")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="83c34a71-a9fc-43a4-a4d2-0e66b872b089")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="638c247a-8212-4ac9-a7fd-b2ec7985f313")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="f1ae5fc6-0b87-458e-8635-c6b887a24958")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="1f60b0df-6616-4e3e-bcbe-74d7f2409f8e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="fbe47663-8bf6-4ed0-b9fe-1344863fd026")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="4567117b-c50f-4917-be35-91eac2a8639d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7ac5d6b2-db40-47d8-b464-df2bd0ddda9d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="a55a24d4-d787-40db-b68c-4c148c4104eb")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8561dc22-4f86-4e7b-8596-64b02b6f9a68")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7b7dabb5-a196-4c31-bd8e-3c1287c3f473")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3af4dbaa-27b9-4783-acce-13e5011fb424")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="04359062-7a2c-4858-8293-5542c836eea0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="4849161c-97ce-40f7-8997-eb90e60bdcd1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3a801247-2a0e-41db-ba14-dfd23f2ca63e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="4990d5a9-043a-4901-94da-74b918f2d0c2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8e67f73f-f070-40cf-a251-2a0d7c2af8f2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="923bc4b2-83f8-4334-bc80-369cda336f5d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="59e094f9-8682-4fe0-9b3a-7579be12e70b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8d4f74ac-09dc-4fb6-884b-094a3f207764")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8b4d864e-195a-4781-8cbb-7095c1a42339")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="135a21d2-2b7e-44df-8f8f-466ffeba2e2b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="09a0bc04-b830-4e7b-a808-73093ea43e82")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="22398a50-72cb-428c-9ee8-4434347eb763")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7d4cd61c-e3be-4afd-9f01-66153b80723c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7ed19dbf-9f2b-4da2-b8e9-426c618ba6dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="9507e351-b4ce-43dc-9a2c-56de79e7a510")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="56030a15-72a9-494e-bd35-0690c22aeee3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="eeb24073-af59-4583-ba91-3411685ec88f")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="78ff3233-47c7-417a-a489-babf10273538")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="cfe48a87-eab0-444c-bccf-7b90d8fe7f81")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="2591abba-754b-4d8e-8b8a-d74c91971fa6")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="dc662241-fab1-41f7-9dcd-e03c18865fc9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="5d5edb66-8739-4dbb-a082-9ed509d73a42")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="23f550b4-d00d-4004-829f-d9573c86eb1c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7bc6b2a6-8248-48b9-8fae-152296f8cd20")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="c188e03b-afdf-4d17-a6cc-b5a5f0b5c92b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7d06bd98-aaa2-4067-9316-66329bc667fc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="e49bd0a7-b650-4964-b83c-c5d4135d4913")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="fffb27a5-b099-43f1-81de-596bd0aad055")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="149e2daf-6480-4aca-ad68-8f0c61c3dbca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="5dd6fbae-3313-41aa-b2b5-fdf74020d111")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="997fc389-80e0-4eae-8449-2b86647dc638")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="f7987ee8-f58b-4d7d-878f-1b3757bb77db")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="40cc798f-e1bc-4670-9a06-a8e55d69860d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="87f52cb3-1932-4240-970d-d533515adfb1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="22ebe324-e7f7-4f7b-8b1e-e79298767b84")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="820de9fc-db34-4b26-a7b9-596c5dbeedab")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="b0fa1783-da18-4c68-9bc0-96330ccb2755")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="7f01cb94-9c1f-4d1d-af44-695441e46473")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="1be5a689-6ebd-49b0-a24c-f8e8189215f9")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="90c11d07-2077-4638-9e2f-b73f9ab46332")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="72da548c-3a37-496e-a848-62c9b67235ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="f45cddd4-1756-436b-a370-3bb9cdb5bce3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="52c3c673-214d-46fa-b96c-d6601bee98fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="abfa237e-568b-489d-8ed3-bb38a66cd035")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3672bffe-9327-4c3a-b524-168877023bb8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="96a57e2f-f7a8-4153-8d28-9171be719c87")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="44ec75d3-21b7-4ef3-95ee-f445af4492ae")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="6348d850-bf74-4e8e-b491-88db0e2d2057")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="c906d3d8-e4a8-4617-8ce1-dc873c8216ef")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="521b0c83-0720-4f1f-82a3-520f0acf1787")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="2d03e578-1bc6-4e76-b91e-ab66706383a3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="20a3424e-87de-4668-83df-c59f201186a1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="508b7492-887a-4c98-b530-b20a1546fd07")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="ea766b97-5598-4ae1-8065-18b9dab3bbc8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="91ede95c-e10b-4f20-a515-1d615ac7b329")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="c2c4a483-6746-4c37-8f8c-dae54e887c19")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="2787df5c-8b5c-46ef-a3b4-420bdcd075a2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="189c6a5e-af1c-4ae2-8c67-e5df117bf850")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="0c155c7d-8ad9-4bad-9271-adf9eb14e5f5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="ac57b2c9-67f9-48d9-95d1-454641b9e4e8")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="5ae546fc-82ab-42be-9dc0-56b268af48ff")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="579e8386-7cfd-4775-85f4-c413beb2fd6d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="0844b55c-30f1-4b73-8400-1d76ede89ec2")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="a1701b36-94d9-48fa-bd08-26fcd62a6e10")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="2c5c5128-958d-4ae4-9492-d82b374c3e59")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="592a402d-e90b-4ee5-a965-2e30c9c5ded5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="a3ea4cd6-908f-46ef-8f51-512ebcf1e0a7")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="363be592-2eed-45f3-8d67-3c1c364d6f64")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="c9e552be-5dc3-4c5a-8371-c46d7249f37d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="de4e45cc-8ac2-4ecf-a0c1-774df695ddd5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="1624d419-1786-4564-91d3-34fee749a99e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="80cbaef7-240a-4348-ae80-c38bfcf5a8dd")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="19125e30-3a91-49f6-a88b-f05121036aa3")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="be4f3507-dd65-4ef7-88b8-da4752417910")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="553b1e03-d295-4c58-adab-01e2007463df")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="8d9a92fa-d7e7-4e67-8f96-17ac4c83b814")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="9406a7b6-5b86-43be-87f8-9a827f346389")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="cace1545-85fa-4029-b21a-fd14b3497f8c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="451aed51-87c4-46f1-a3ad-5ed67ffd7071")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="3946f62b-1a7b-4f08-8d4d-337caea53db0")>]

# %%
for maker in makers :
    brandName = maker.find_element_by_tag_name('span').text
    #print(brandName)
    if brandName != '' :
        print(brandName.strip())
        img = maker.find_element_by_tag_name('img').get_attribute('src')
        print(img)
        link = maker.find_element_by_tag_name('a').get_attribute('href')
        print(link)
    print('*'*50)
nextBtn.click
# Out:
# 현대
# https://imgauto-phinf.pstatic.net/20180529_88/auto_1527592677868AxMTJ_PNG/20180529201748_nbVe4EOk.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=16&importYn=N
# **************************************************
# 기아
# https://imgauto-phinf.pstatic.net/20210107_250/auto_16099798594392UWMl_PNG/20210107093730_Bmgw8HVj.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=12&importYn=N
# **************************************************
# 제네시스
# https://imgauto-phinf.pstatic.net/20210302_296/auto_1614669701772Y34jY_PNG/20210302162133_MyAzBxsu.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=61321&importYn=N
# **************************************************
# 르노삼성
# https://imgauto-phinf.pstatic.net/20170707_188/auto_14994089761732i2AM_PNG/20170707152934_4UQVPJ4f.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=15&importYn=N
# **************************************************
# 쌍용
# https://imgauto-phinf.pstatic.net/20170707_290/auto_14994089867715m7Kc_PNG/20170707152945_ov1NwuMf.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=13&importYn=N
# **************************************************
# 폭스바겐
# https://imgauto-phinf.pstatic.net/20200422_10/auto_15875288567367G6VE_PNG/20200422131406_lmRMWJht.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=20&importYn=Y
# **************************************************
# 벤츠
# https://imgauto-phinf.pstatic.net/20170707_151/auto_1499404806991Xuw2o_PNG/20170707142004_4ANaTv3h.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=21&importYn=Y
# **************************************************
# BMW
# https://imgauto-phinf.pstatic.net/20200310_214/auto_1583815678479PKzIr_PNG/20200310134752_3hMT5CTc.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=23&importYn=Y
# **************************************************
# 아우디
# https://imgauto-phinf.pstatic.net/20170707_207/auto_1499404828979BICft_PNG/20170707142026_ovRGcdML.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=18&importYn=Y
# **************************************************
# 렉서스
# https://imgauto-phinf.pstatic.net/20170707_52/auto_14994086479909zBvg_PNG/20170707152405_Q81trl9v.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=22&importYn=Y
# **************************************************
# 토요타
# https://imgauto-phinf.pstatic.net/20210106_265/auto_16098924526573ov6n_PNG/20210106092042_1U9hpa8L.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=41&importYn=Y
# **************************************************
# 혼다
# https://imgauto-phinf.pstatic.net/20170707_163/auto_1499412516283v1k4a_PNG/20170707162834_NTGXoypb.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=31&importYn=Y
# **************************************************
# 볼보
# https://imgauto-phinf.pstatic.net/20170707_20/auto_1499407892646zwj3j_PNG/20170707151130_ECGx0tRI.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=24&importYn=Y
# **************************************************
# 미니
# https://imgauto-phinf.pstatic.net/20170718_248/auto_1500352107292eUlzC_PNG/20170718132824_jfupLnkX.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=6435&importYn=Y
# **************************************************
# 재규어
# https://imgauto-phinf.pstatic.net/20200210_83/auto_1581307501553E0yRR_PNG/20200210130456_nFc7LE10.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=25&importYn=Y
# **************************************************
# 랜드로버
# https://imgauto-phinf.pstatic.net/20170707_56/auto_1499407965482n6u8s_PNG/20170707151243_JgB80ept.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=39&importYn=Y
# **************************************************
# 포드
# https://imgauto-phinf.pstatic.net/20210105_233/auto_1609826474487Qo1XI_PNG/20210105150107_0owl8Al4.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=30&importYn=Y
# **************************************************
# 링컨
# https://imgauto-phinf.pstatic.net/20200210_259/auto_1581306902625KDGxC_PNG/20200210125456_MTfaDdcX.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=35&importYn=Y
# **************************************************
# 쉐보레
# https://imgauto-phinf.pstatic.net/20200210_175/auto_15813076774623FdaV_PNG/20200210130752_EvOsbnkP.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=48&importYn=Y
# **************************************************
# 캐딜락
# https://imgauto-phinf.pstatic.net/20200210_173/auto_1581307884356S76fk_PNG/20200210131119_926jfS5j.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=19&importYn=Y
# **************************************************
# 테슬라
# https://imgauto-phinf.pstatic.net/20200207_106/auto_1581062693327I8zB8_PNG/20200207170452_onbaYnni.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=29832&importYn=Y
# **************************************************
# 지프
# https://imgauto-phinf.pstatic.net/20210105_78/auto_1609827518081uIbLF_PNG/20210105151828_vhnCFC3o.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=40&importYn=Y
# **************************************************
# 르노
# https://imgauto-phinf.pstatic.net/20170707_144/auto_1499408879255Wd6hc_PNG/20170707152757_lWFu4xfw.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3847&importYn=Y
# **************************************************
# 푸조
# https://imgauto-phinf.pstatic.net/20210226_26/auto_1614310028069dFaSb_PNG/20210226122657_FXxr6OOE.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=28&importYn=Y
# **************************************************
# 시트로엥
# https://imgauto-phinf.pstatic.net/20181108_18/auto_1541652035025xL7p3_PNG/20181108133955_yc5nqMrw.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3848&importYn=Y
# **************************************************
# DS
# https://imgauto-phinf.pstatic.net/20190107_113/auto_1546853570990Bvdb4_PNG/20190107182820_B7nzxr1b.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=128687&importYn=Y
# **************************************************
# 마세라티
# https://imgauto-phinf.pstatic.net/20200204_64/auto_15807923347514cszg_PNG/20200204135847_DtWGDHvi.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3976&importYn=Y
# **************************************************
# 포르쉐
# https://imgauto-phinf.pstatic.net/20170707_204/auto_1499412493946IUcqn_PNG/20170707162812_UHBa49m6.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3905&importYn=Y
# **************************************************
# 람보르기니
# https://imgauto-phinf.pstatic.net/20170707_125/auto_14994122235148asnx_PNG/20170707162341_CqMN8SjK.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3814&importYn=Y
# **************************************************
# 페라리
# https://imgauto-phinf.pstatic.net/20170707_281/auto_1499408535368ecSNr_PNG/20170707152213_nyTypfsh.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=27&importYn=Y
# **************************************************
# 맥라렌
# https://imgauto-phinf.pstatic.net/20190926_229/auto_15694874534572Fs1o_PNG/20190926174407_RwH9JfF9.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=29978&importYn=Y
# **************************************************
# 부가티
# https://imgauto-phinf.pstatic.net/20170707_285/auto_1499408935383JGknW_PNG/20170707152853_4k680tvB.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=58745&importYn=Y
# **************************************************
# 애스턴마틴
# https://imgauto-phinf.pstatic.net/20170707_46/auto_1499408032205ouvHE_PNG/20170707151349_r4p7RZOj.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3827&importYn=Y
# **************************************************
# 마이바흐
# https://imgauto-phinf.pstatic.net/20170707_277/auto_1499412250805hiM8q_PNG/20170707162409_mSzWlZ24.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=6434&importYn=Y
# **************************************************
# 롤스로이스
# https://imgauto-phinf.pstatic.net/20170707_262/auto_14994080191477VFT5_PNG/20170707151337_vgZPLDwZ.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=3824&importYn=Y
# **************************************************
# 벤틀리
# https://imgauto-phinf.pstatic.net/20170707_290/auto_1499408006740euBhj_PNG/20170707151324_gQBpIQqz.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=4129&importYn=Y
# **************************************************
# 닛산
# https://imgauto-phinf.pstatic.net/20210105_89/auto_1609825595273uqmlr_PNG/20210105144621_ezZp9kFk.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=33&importYn=Y
# **************************************************
# 로터스
# https://imgauto-phinf.pstatic.net/20170707_97/auto_1499408040746dxIos_PNG/20170707151359_E4SArp8Q.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=4040&importYn=Y
# **************************************************
# 마쯔다
# https://imgauto-phinf.pstatic.net/20170707_140/auto_14994122738541Fk5N_PNG/20170707162432_2Lw7mMJS.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=42&importYn=Y
# **************************************************
# 미쓰비시
# https://imgauto-phinf.pstatic.net/20200207_201/auto_1581062586549FXM8u_PNG/20200207170304_BOBWwF1a.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=37&importYn=Y
# **************************************************
# 복스홀
# https://imgauto-phinf.pstatic.net/20200821_129/auto_1597968282651s2erz_PNG/20200821090431_zWaArvD8.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=29989&importYn=Y
# **************************************************
# 뷰익
# https://imgauto-phinf.pstatic.net/20170707_147/auto_1499405021719vSD1c_PNG/20170707142339_e4H9pYvp.png?type=f30_30
# https://auto.naver.com/company/main.nhn?mnfcoNo=43&importYn=Y
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# **************************************************
# <bound method WebElement.click of <selenium.webdriver.remote.webelement.WebElement (session="485a97fdf9a7e9d78b44f5a3c33efd80", element="80b80468-18a3-4b2b-87d6-a0f09b240e30")>>

# %%
# nextBtn
nextBtn = driver.find_element_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.rolling_btn > button.next')
isFlag = nextBtn.is_enabled()
print(isFlag)
# Out:
# True

# %%
nextBtn = driver.find_element_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.rolling_btn > button.next')
isFlag  = nextBtn.is_enabled()
cnt     = isFlag

for idx in range(len(cnt)) :
    makers = driver.find_elements_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.emblem_area > ul > li')
    makers
    for maker in makers :
        brandName = maker.find_element_by_tag_name('span').text
        #print(brandName)
        if brandName != '' :
            print(brandName.strip())
            img = maker.find_element_by_tag_name('img').get_attribute('src')
            print(img)
            link = maker.find_element_by_tag_name('a').get_attribute('href')
            print(link)
        print('*'*50)
    nextBtn.click()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-83ded2799098> in <module>
#       3 cnt     = isFlag
#       4
# ----> 5 for idx in range(len(cnt)) :
#       6     makers = driver.find_elements_by_css_selector('#_vendor_select_layer > div > div.maker_group > div.emblem_area > ul > li')
#       7     makers
#
# TypeError: object of type 'bool' has no len()

# %%
### xpath
- 절대경로를 이용한 노드 탐색
- 노드선택 (nodename , / , //, @ 속성을의미)
- <div name ='test'>
- driver.find_element_by_xpath('//div[@name]')
- * 매칭되는 모든 요소
- @* 매칭되는 모든 속성의 노드

# %%
#_vendor_select_layer > div > div.maker_group > div:nth-child(2) > ul > li:nth-child(1) > a

document.querySelector("#_vendor_select_layer > div > div.maker_group > div:nth-child(2) > ul > li:nth-child(1) > a")
//*[@id="_vendor_select_layer"]/div/div[1]/div[2]/ul/li[1]/a
//*[@id="_vendor_select_layer"]/div/div[1]/div[2]/ul/li[1]/a
# Out:
#   File "<ipython-input-130-44c00b12ea76>", line 4
#     //*[@id="_vendor_select_layer"]/div/div[1]/div[2]/ul/li[1]/a
#     ^
# SyntaxError: invalid syntax

# %%
path = './driver/Chromedriver.exe'
driver = webdriver.Chrome(path)
driver
# Out:
# <selenium.webdriver.chrome.webdriver.WebDriver (session="e698fed0952e9be340bb83c40afbe0c9")>

# %%
driver.get('http://deal.11st.co.kr/html/nc/deal/main.html')

# %%
lis = driver.find_elements_by_css_selector('#emergencyPrd > div > ul > li')
len(lis)

for li in lis :
    title = li.find_element_by_css_selector('div > a > div.prd_info > p > span.fs_16')
    price = li.find_element_by_css_selector('div > a > div.prd_info > div > span.price_detail > strong')
    print(title.text)
    print(price.get_attribute('innerHTML'))
    print('*'*50)
# Out:
# [상담완료고객 스벅 커피쿠폰증정]아라봄 신차 장기렌터카 무보증 0원 비교견적/수입차전차종/국산차전차종/BMW/더뉴그랜져/팰리세이드/아반떼
# 239,000
# **************************************************
# [마니커F&G]바사삭치킨한마리 500g(2봉) + 바사삭순살치킨 400g/옛날통닭/너겟/통다리
# 19,900
# **************************************************
# 시디즈 베스트셀러 탭/링고/아이블/T25/T40/T50
# 149,900
# **************************************************
# [프롬비기닝]~55% 3만원할인+1천원! 신상&인기업댓! 봄코디는 비기닝! 자켓/셔츠/팬츠/가디건/원피스
# 16,200
# **************************************************
# [25%쿠폰][헤지스/닥스ACC 외] 시즌 BEST 단독 특가 행사! 가방/지갑/잡화 모음전
# 31,200
# **************************************************
# 삼성전자 그랑데 AI 올인원컨트롤 건조기+세탁기 세트 DV16T9720SW+WF21T9500KW
# 2,079,000
# **************************************************
# 아우라 건조기용 드라이시트120매x2개+증정20매
# 30,900
# **************************************************
# [빈폴키즈][20%+5%더블쿠폰+무배] 신상의류 & 신학기 가방 득템찬스
# 29,000
# **************************************************
# ["15+5%쿠폰"]
# 125,910
# **************************************************
# [앤디애플]봄신상 BEST 모음/봄코디룩/등원룩/아동복/유아복/티셔츠/상하복/원피스/레깅스/스커트/점퍼
# 8,800
# **************************************************
# [풀무원] 월간 핫도그(올바른/모짜렐라/탱글뽀득/체다모짜)+[증] 하인즈케첩460g
# 23,310
# **************************************************
# [17%혜택+추가+상품권] 삼성 갤럭시워치3 41mm 45mm 블루투스 스마트워치 모음
# 429,000
# **************************************************
# [15%+10%+T11%] 아모레퍼시픽 놓칠수 없는 기회! 라네즈/아이오페/한율/마몽드 BEST 전국민세일~50%
# 21,000
# **************************************************
# 코카콜라[본사직영] 코크제로 캔 355ml 24개
# 18,310
# **************************************************
# [60%쿠폰+22%T][슈나이더]봄맞이 남녀 인기패션 아이템 아우터 티셔츠 팬츠 바지 자켓 베스트 맨투맨
# 11,800
# **************************************************
# [15%+15%쿠폰][크록스본사]크록스 시즌 오픈! 신상 입고 십일절 최대 67%
# 19,360
# **************************************************
# [슈마커]30%+11%,아디다스/푸마 신상 슬라이드 운동화 뮬 백팩
# 17,000
# **************************************************
# 갤럭시 탭 A7 64G
# 214,000
# **************************************************
# [에이블루] 커블체어 자세교정 좌식의자 2+1 EVENT
# 46,900
# **************************************************
# [조르지오 아르마니] 디자이너 리프트 파운데이션 세트 (+립 마에스트로 정품+컨실러 미니어처+기프트백)
# 74,460
# **************************************************
# [ALL STANDARD] ECO 무라벨 생수 2L / 500ML
# 3,300
# **************************************************
# [10%+33%+복수할인] 허니삭스 봄신상 페이크삭스/무지/캐릭터 패션양말 시즌 세일
# 8,900
# **************************************************
# [최종구매가362,400원] 삼성 오디세이 G5 C32G54T QHD 144Hz 1ms 게이밍모니터
# 419,000
# **************************************************
# [20%+10%]질레트 16입/10입 대용량 면도날+캠핑의자or면도기&미니거치대외 특별증정
# 65,000
# **************************************************
# [20%+10%]헤드앤숄더 BEST 대용량 모음전
# 15,250
# **************************************************
# 3월 신데렐라 땡처리 아디다스 스니커즈 외 나이키 스포츠양말 인기 에어맥스 운동화 런닝화 신발
# 10,000
# **************************************************
# 100%국산자재 참조은 KF94 마스크 화이트 블랙 소형 대형 100매- 식약처인증 미세먼지 어린이
# 27,800
# **************************************************
# [일룸] 링키 or 링키 스마트 책상 + 시디즈 링고 의자 / 정면 각도 조절 초등 학생 책상 의자 포함 세트
# 319,000
# **************************************************
# 노스페이스 남녀 SS 신상&이월 베스트 의류모음 등산 자켓/반팔티/후드/팬츠/쇼츠 외
# 20,000
# **************************************************
# [선물하기 109.9만원+김치쿠폰증정] 21년형 딤채 스탠드 김치냉장고 SDT33EFRZDT (330L/3룸) 공식판매점
# 1,129,000
# **************************************************

# %%
lis_01 = driver.find_elements_by_xpath('//*[@id="emergencyPrd"]/div/ul/li[position() <= 2]')
len(lis_01)


for li in lis_01 :
    title = li.find_element_by_xpath('div/a/div[3]/p/span[2]')
    price = li.find_element_by_xpath('div/a/div[3]/div/span/strong')
    print(title.text)
    print(price.get_attribute('innerHTML'))
    print('*'*50)
# Out:
# [상담완료고객 스벅 커피쿠폰증정]아라봄 신차 장기렌터카 무보증 0원 비교견적/수입차전차종/국산차전차종/BMW/더뉴그랜져/팰리세이드/아반떼
# 239,000
# **************************************************
# [마니커F&G]바사삭치킨한마리 500g(2봉) + 바사삭순살치킨 400g/옛날통닭/너겟/통다리
# 19,900
# **************************************************

# %% [markdown]
# ### page 처리

# %%
from time import sleep, time
from random import randint
from IPython.core.display import clear_output
from requests import get

# %%
start_time = time ()
requests = 0 
for i in range (5):
    requests += 1
    sleep(randint(1,3))
    current_time = time()
    delayed_time = current_time - start_time
    print('request {}, time {}'.format(requests, requests/delayed_time))
    clear_output(wait=True)
# Out:
# request 5, time 0.6200044405301556

# %%
url = 'https://www.ildong.com/kor/product/list.id?page=1&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0'
path = './driver/Chromedriver.exe'
driver = webdriver.Chrome(path)
driver.get(url)

# %%
for page in range(1,10) : 
    url = 'https://www.ildong.com/kor/product/list.id?page='+str(page)+'&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0'
    driver.get(url)
    prList = driver.find_element_by_class_name('prList')
    tags = prList.find_elements_by_tag_name('a')

    for idx in range(0,9) :
        tags[idx].click()
        prdName = driver.find_element_by_class_name('detailCnt2')
        print(prdName.text)
        print('*'*50)
        driver.back()

        prList = driver.find_element_by_class_name('prList')
        tags = prList.find_elements_by_tag_name('a')
# Out:
# 제품특징
#
# 보스웰리아 추출물 + 칼슘
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(4정) 당
# 칼슘 : 390.77 mg
# AKBA와 KBA의 합 : 71 mg
#   ※우유, 게 함유
#
#
# 기능정보
#
# <기능정보>
# [칼슘]1. 뼈와 치아 형성에 필요, 2. 신경과 근육 기능 유지에 필요, 3. 정상적인 혈액응고에 필요, 4. 골다공증발생 위험 감소에 도움을 줌
# [보스웰리아 추출물]관절 및 연골 건강에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 2정을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 120정 X 2개입(240 g)
# **************************************************
# 제품특징
#
# 특허받은 4중코팅, 100억 유산균
# 50년 이상 유산균 연구
# 3중 복합기능성
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU 이상
# 아연 : 8.5 mg
# 비타민D : 5 ㎍
#   ※대두, 우유 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스 제품] 1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음.
#                              2. 배변활동 원활에 도움을 줄 수 있음.
# [아연] 1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비타민D] 1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐(0.5g)을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐 X 2개입
# **************************************************
# 제품특징
#
# 장까지 살아가는 生유산균
# 4중코팅 유산균 특허
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1회 섭취량(1포) 당
# 프로바이오틱스 수 : 50,000,000 CFU 이상
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음
#                       2. 배변활동원활에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 3회, 1회 1포를 섭취하십시오.
#
#
# 포장단위
#
# 2 g X 100포(200 g)
# **************************************************
# 제품특징
#
# 100억 유산균
# 특허받은 4중 코팅
# 4중 복합기능성
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU 이상
# 아연 : 8.5 mg
# 셀레늄 : 21 μg
# 비타민D : 5 μg
#   ※대두, 우유, 쇠고기, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동원활에 도움을 줄 수 있음
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [셀레늄]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐(30 g)
# **************************************************
# 제품특징
#
# 간건강에 도움을 주는 밀크씨슬
# 지친 간을 위한 자연의 선물, 밀크씨슬
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 실리마린 : 130 mg
#   ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [실리마린]간 건강에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 750 mg X 30캡슐(22.5 g)
# **************************************************
# 제품특징
#
# 100억 프로바이오틱스
# 장까지 살아가는 4중 코팅 특허 유산균
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU
#   ※우유, 대두, 쇠고기, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 30캡슐(15 g)
# **************************************************
# 제품특징
#
# 중년 남성을 위한 6가지 기능성으로 더욱 당당하게, 더욱 상쾌하게!
# 쏘팔메토 추출물, 아연, 비타민B6, 옥타코사놀
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 쏘팔메토 열매추출물 : 로르산 70 mg
# 아연 : 30 mg
# 옥타코사놀 함유 유지 : 옥타코사놀 40 mg
# 비타민B6 : 15 mg
#   ※토마토, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [쏘팔메토 열매추출물]전립선 건강의 유지에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [옥타코사놀 함유 유지]지구력 증진에 도움을 줄 수 있음
# [비타민B6] 단백질 및 아미노산 이용에 필요, 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐(30 g)
# **************************************************
# 제품특징
#
# 내 아기를 위한 필수 영양성분, 레몬에서 나온 엽산
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1정) 당
# 엽산 : 1,000 μg
#
#
# 기능정보
#
# <기능정보>
# [엽산]1. 세포와 혈액 생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1정을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60정(30 g)
# **************************************************
# 제품특징
#
# 눈 건강을 위한 프리미엄 레시피
# 루테인지아잔틴복합추출물 20%, EPA 및 DHA 함뮤 유지, 비타민E
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(2캡슐) 당
# 비타민E : 3.3 mg α-TE
# 루테인 : 16 mg
# 지아잔틴 : 4 mg
# EPA와 DHA의 합 : 600 mg
# ※대두, 쇠고기, 고등어 함유
#
#
# 기능정보
#
# <기능정보>
# [루테인지아잔틴복합추출물20%]노화로 인해 감소될 수 있는 황반색소밀도를 유지시켜 주어 눈 건강에 도움을 줌
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 건조한 눈을 개선하여 눈 건강에 도움을 줄 수 있음
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60캡슐(60 g)
# **************************************************
# 제품특징
#
# 하루 영양, 하루 활력, 17종 비타민과 미네랄
# 건강한 임신을 위한 맞춤형 포뮬러
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 철 : 36 mg
# 비타민C : 110 mg
# 셀렌 : 60 μg
# 비타민E : 12 mg α-TE
# 나이아신 : 18 mg NE
# 아연 : 10.5 mg
# 판토텐산 : 6 mg
# 망간 : 2 mg
# 비타민A : 470 μg RE
# 비타민D : 10 μg
# 비오틴 : 30 μg
# 구리 : 0.93 mg
# 비타민B12 : 2.6 μg
# 비타민B6 : 2.21 mg
# 비타민B1 : 1.5 mg
# 비타민B2 : 1.6 mg
# 엽산 : 800 μg
#
#
# 기능정보
#
# <기능정보>
# [철]1. 체내 산소운반과 혈액생성에 필요, 2. 에너지 생성에 필요
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [나이아신] 체내 에너지 생성에 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [판토텐산]자방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [망간]1. 뼈 형성에 필요, 2. 에너지 이용에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [구리]1. 철의 운반과 이용에 필요, 2.  유해산소로부터 세포를 보호하는데 필요
# [비타민B12]정상적인 엽산 대사에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2정을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 750 mg X 60정(45 g)
# **************************************************
# 제품특징
#
# 자연발효가 만들어 낸 맥주효모&건조효모
# 활력과 풍성한 생활의 비결
#
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(8정) 당
# 비타민B1 : 0.53 mg
# 비타민B2 : 0.45 mg
# 나이아신 : 4.51 mg NE
# 판토텐산 : 1. 55 mg
# 비타민B6 : 0.55 mg
# 엽산 : 152 μg
# 비오틴 : 42 μg
# 셀렌 : 28 μg
# 아연 : 2.82 mg
# 크롬 : 28 μg
#
#
# 기능정보
#
# <기능정보>
# [비타민B1]탄수화물과 에너지 대사에 필요
# [비타민B2]체내 에너지 생성에 필요
# [나이아신]체내 에너지 생성에 필요
# [판토텐산]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [엽산]1. 세포와 혈액생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 4정을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 120정(60 g)
# **************************************************
# 제품특징
#
# 기억력과 인지력 개선에 도움을 줄 수 있는 두뇌건강 솔루션
# 포스파티딜세린, 은행잎 추출물, 비타민E
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 포스파티딜세린 : 300 mg
# 은행잎 추출물 : 플라보놀 배당체 28 mg
# 비타민E : 22 mg α-TE
#   ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [포스파티딜세린]노화로 인해 저하된 인지력 개선·자외선에 의한 피부 손상으로부터 피부 건강 유지·피부보습에 도움을 줄 수 있음
# [은행잎 추출물]1. 기억력 개선에 도움을 줄 수 있음, 2. 혈행 개선에 도움을 줄 수 있음
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60캡슐(60 g)
# **************************************************
# 제품특징
#
# 식물성 EPA 및 DHA 함유 유지와 식물성 캡슐
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 비타민D : 10 μg
# EPA와 DHA의 합 : 500 mg
#
#
# 기능정보
#
# <기능정보>
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선, 2. 혈행 개선에 도움을 줄 수 있음
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 510 mg X 60캡슐(30.6 g)
# **************************************************
# 제품특징
#
# 우리 엄마, 다시 봄이 활짝 피었습니다.
# 백수오 등 복합추출물, 비타민E, 비타민D, 비타민B1
#
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(1포) 당
# 백수오 등 복합추출물 : 514 mg (Nodakenin 2.0046 mg, Shanzhiside methylester 0.257 mg, Cinnamic acid 5.14 μg)
# 비타민E : 11 mg α-TE
# 비타민D : 5 μg
# 비타민B1 : 1.35 mg
#
#
# 기능정보
#
# <기능정보>
# [백수오 등 복합추출물]갱년기 여성의 건강에 도움을 줄 수 있음
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [비타민B1]탄수화물과 에너지 대사에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 25 g X 15포(375 g)
# **************************************************
# 제품특징
#
# 현대인의 풍성한 행복
# 프랑스산 프리미엄 비오틴
# 맥주효모, 피쉬콜라겐, 아미노산 믹스 8종(보조원료)
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1정) 당
# 비오틴 : 5,000 μg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1정을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 300 mg X 60정(18 g)
# **************************************************
# 제품특징
#
# 하루 3개로 비타민C 100 mg
# 유해산소로부터 세포를 보호하는데 필요
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(3개) 당
# 비타민C : 100 mg
#   ※대두, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 3회, 1회 1개를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 3 g X 12개(36 g)
# **************************************************
# 제품특징
#
# 영국산 프리미엄 비타민C
# 맛있는 비타민C
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 비타민C : 500 mg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 입안에서 녹여 섭취하십시오.
#
#
# 포장단위
#
# 2 g X 60포(120 g)
# **************************************************
# 제품특징
#
# 맛있는 비타민C, 내 몸의 필수 영양성분
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1정) 당
# 비타민C : 100 mg
# ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1정씩 입안에서 녹이거나 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,600 mg X 120정 (192 g)
# **************************************************
# 제품특징
#
# 뼈 건강을 지키는 건강한 습관
# 스위스산 프리미엄 비타민D3
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 비타민D : 125 μg
#   ※우유, 대두, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 280 mg X 90캡슐(25.2 g)
# **************************************************
# 제품특징
#
# 혈행가선을 위한 프리미엄 성분들의 황금배합
# 유해산소로부터 세포를 보호하는 비타민C·E와 항산화 미네랄 셀레늄
# 하루 1정, 8가지 기능성으로 몸을 관리하세요!
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 플라보놀 배당체: 36 mg
# 비타민A: 700 μg RE
# 비타민C: 100 mg
# 비타민E: 11 mg α-TE
# 셀레늄: 55 μg
# ※ 우유 함유
#
#
# 기능정보
#
# <기능정보>
# [은행잎 추출물]기억력 개선에 도움을 줄 수 있음, 혈행개선에 도움을 줄 수 있음
# [비타민A]어두운 곳에서 시각 적응을 위해 필요, 피부와 점막을 형성하고 기능을 유지하는데 필요, 상피세포의 성장과 발달에 필요
# [비타민C]결합조직 형성과 기능유지에 필요, 철의 흡수에 필요, 유해산소로부터 세포를 보호하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [셀레늄]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1정를 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,100 mg x 60정 x 2개입 (132 g)
# **************************************************
# 제품특징
#
# 가르시니아캄보지아 추출물 함유
# 탄수화물 위주 식습관인 한국인 맞춤 체지방감소 기능성
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(6개) 당
# 총(-)-Hydroxycitric acid : 750 mg
# ※ 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [가르시니아캄보지아 추출물]탄수화물이 지방으로 합성되는 것을 억제하여 체지방 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 3개를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 3 g X 12개(36 g)
# **************************************************
# 제품특징
#
# 홍경천추출물, 비타민B12, 비타민B1, 비타민B6, 비타민B2, 나이아신, 판토텐산, 엽산, 비오틴
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 비타민B1 : 50 mg
# 비타민B2 : 50 mg
# 비타민B6 : 50 mg
# 비타민B12 : 500 μg
# 나이아신 : 50 mg NE
# 판토텐산 : 50 mg
# 엽산 : 500 μg
# 비오틴 : 50 μg
# 로사빈 : 5 mg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [홍경천 추출물]스트레스로 인한 피로개선에 도움을 줄 수 있음
# [비타민B1]탄수화물과 에너지 대사에 필요
# [비타민B2]체내 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B12]정상적인 엽산 대사에 필요
# [나이아신] 체내 에너지 생성에 필요
# [판토텐산]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [엽산]1. 세포와 혈액생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2정을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 800 mg X 60정(48 g)
# **************************************************
# 제품특징
#
# 현대인의 스트레스로 인한 피로 관리
# 활력비타민B군, 홍경천 추출물
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 비타민B1 : 100 mg
# 비타민B2 : 100 mg
# 나이아신 : 100 mg NE
# 판토텐산 : 100 mg
# 비타민B6 : 100 mg
# 엽산 : 1,000 μg
# 비타민B12 : 1,000 μg
# 비오틴 : 100 μg
# 로사빈 : 5 mg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민B1]탄수화물과 에너지 대사에 필요
# [비타민B2]체내 에너지 생성에 필요
# [나이아신] 체내 에너지 생성에 필요
# [판토텐산]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [엽산]1. 세포와 혈액생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B12]정상적인 엽산 대사에 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [홍경천 추출물]스트레스로 인한 피로개선에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2정을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 800 mg X 60정(48 g)
# **************************************************
# 제품특징
#
# 오염된 환경에서 살아가는 현대인의 필수품
# 자연발효공법으로 생산한 코엔자임Q10
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 코엔자임Q10 : 100 mg
#   ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [코엔자임Q10]항산화·높은 혈압 감소에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 400 mg X 30캡슐(12 g)
# **************************************************
# 제품특징
#
# 눈 건강에 필요한 필수 성분들로만 꽉
# 루테인지아잔틴복합추출물20%, 비타민C, 비타민E, EPA 및 DHA 함유 유지
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 비타민C : 250 mg
# 비타민E : 134.2 mg α-TE
# 구리 : 1 mg
# 아연 : 12 mg
# 루테인 : 10.8 mg
# 지아잔틴 : 2.7 mg
# 베타카로틴 : 7 mg
# EPA와 DHA의 합 : 640 mg
#   ※대두, 쇠고기, 고등어 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [구리]1. 철의 운반과 이용에 필요, 2. 유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [루테인지아잔틴복합추출물20%]노화로 인해 감소될 수 있는 황반색소밀도를 유지시켜 주어 눈 건강에 도움을 줌
# [베타카로틴]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 건조한 눈을 개선하여 눈 건강에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60캡슐(60 g)
# **************************************************
# 제품특징
#
# 혈행개선과 기억력개선을 동시에! 건조한 눈을 촉촉하게!
# 흡수가 용이한 EPA 및 DHA 함유 유지
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# EPA와 DHA의 합 : 1,000 mg
#   ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 기억력 개선에 도움을 줄 수 있음, 3. 건조한 눈을 개선하여 눈 건강에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 625 mg X 60캡슐(37.5 g)
# **************************************************
# 제품특징
#
# 혈행개선과 기억력개선을 동시에! 건조한 눈을 촉촉하게!
# 흡수가 용이한 EPA 및 DHA 함유 유지
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(2캡슐) 당
# EPA와 DHA의 합 : 1,000 mg
# 비타민E : 11 mg α-TE
# ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 기억력 개선에 도움을 줄 수 있음, 3. 건조한 눈을 개선하여 눈 건강에 도움을 줄 수 있음
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 640 mg X 60캡슐(38.4 g)
# **************************************************
# 제품특징
#
# 성장기 어린이를 위한 맞춤 영양밸런스
# 새콤달콤 오렌지맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(3정) 당
# 비타민A : 675 μg RE
# 비타민D : 7.5 μg
# 비타민E : 10.5 mg α-TE
# 비타민K : 45 μg
# 비타민B1 : 1.5 mg
# 비타민B2 : 1.5 mg
# 나이아신 : 12 mg NE
# 판토텐산 : 3.75 mg
# 비타민B6 : 1.5 mg
# 비오틴 : 90 μg
# 엽산 : 400 μg
# 비타민B12 : 3.9 μg
# 비타민C : 90 mg
# 철 : 9 mg
# 아연 : 8.5 mg
# 셀렌 : 53 μg
# 망간 : 1.35 mg
#   ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [비타민K]1. 정상적인 혈액응고에 필요, 2. 뼈의 구성에 필요
# [비타민B1]탄수화물과 에너지 대사에 필요
# [비타민B2]체내 에너지 생성에 필요
# [나이아신]체내 에너지 생성에 필요
# [판토텐산]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [엽산]1. 세포와 혈액생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B12]정상적인 엽산 대사에 필요
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [철]1. 체내 산소운반과 혈액생성에 필요, 2. 에너지 생성에 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [망간]1. 뼈 형성에 필요, 2. 에너지 이용에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 3회, 1회 1정을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,500 mg X 45 정(67.5 g)
# **************************************************
# 제품특징
#
# 튼튼한 우리아이를 위해 매일매일  맛있는 영양
# 5가지 비타민과 미네랄
# 새콤한 사과맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 비타민B1 : 0.7 mg
# 나이아신 : 8.4 mg NE
# 비타민B6 : 0.7 mg
# 비타민E : 5 mg α-TE
# 아연 : 4.7 mg
#
#
# 기능정보
#
# <기능정보>
# [비타민B1]탄수화물과 에너지 대사에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [나이아신] 체내 에너지 생성에 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 15 g X 15포(225 g)
# **************************************************
# 제품특징
#
# 키즈 신바이오틱스(프로바이오틱스+프리바이오틱스)
# 프로바이오틱스(유산균) 50억, 개별인정형원료 자일로올리고당, 아연
# 요구르트맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 프로바이오틱스 수 : 5,000,000,000 CFU
# 아연 : 5 mg
# 자일로올리고당 : 700 mg
#   ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [자일로올리고당]1. 장내 유익균 증식, 2. 유해균 억제, 3. 배변활동에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포를 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 2,500 mg X 30포(75 g)
# **************************************************
# 제품특징
#
# 우리아이 장건강 & 정상적인 면역기능
# 프로바이오틱스, 아연
# 새콤달콤 포도맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 프로바이오틱스 수 : 1,000,000,000 CFU
# 아연 : 5 mg
#   ※대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1정를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60정(60 g)
#
# **************************************************
# 제품특징
#
# 맛있게 씹어먹는 아연·비타민C
# 착색료, 합성향료, 설탕 무첨가
# 새콤달콤 딸기맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 비타민C : 100 mg
# 아연 : 8 mg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1정을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,500 mg X 30정(45 g)
# **************************************************
# 제품특징
#
# 자연의 영양 그대로 풍성하게, 맥주효모 & 건조효모
# 풍성한 생활의 비결, 비오틴 & 판토텐산
#
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(8정) 당
# 비타민B1 : 0.36 mg
# 판토텐산 : 10 mg
# 비오틴 : 1,000 μg
# 아연 : 8 mg
#
#
# 기능정보
#
# <기능정보>
# [비타민B1]탄수화물과 에너지 대사에 필요
# [판토텐산]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 4정을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# (500 mg X 120정) X 2개입 (120 g)
# **************************************************
# 제품특징
#
# 혈행 개선을 위한 프리미엄 성분들의 황금배합!!
# 막힘없는 혈액순환
# 은행잎추추물, 감미리놀렌산 함유 유지, 비타민C, 비타민E
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 은행잎추출물 : 103.7 mg (플라보놀 배당체 28 mg)
# 감마리놀렌산 : 240 mg
# 비타민C : 500 mg
# 비타민E : 134 mg α-TE
#   ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [은행잎추출물]1. 기억력 개선에 도움을 줄 수 있음, 2. 혈행 개선에 도움을 줄 수 있음
# [감마리놀렌산 함유 유지]1. 혈중 콜레스테롤 개선·혈행개선에 도움을 줄 수 있음, 2. 월경전 변화에 의한 불편한 상태 개선에 도움을 줄 수 있음, 3. 면역과민반응에 의한 피부상태 개선에 도움을 줄 수 있음
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,250 mg X 60캡슐(75 g)
# **************************************************
# 제품특징
#
# 남성을 위한 멀티비타민과 미네랄
# 활력비타민 B군 강화
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 마그네슘 : 100 mg
# 비타민E : 30 mg α-TE
# 비타민C : 100 mg
# 비타민B1 : 50 mg
# 판토텐산 : 50 mg
# 비타민B6 : 50 mg
# 비타민B2 : 50 mg
# 셀렌 : 60 μg
# 나이아신 : 16 mg NE
# 아연 : 12 mg
# 비오틴 : 100 μg
# 비타민A : 600 μg RE
# 비타민B12 : 50 μg
# 비타민D : 10 μg
# 망간 : 1 mg
# 구리 : 0.4 mg
# 엽산 : 400 μg
#   ※우유, 토마토 함유
#
#
# 기능정보
#
# <기능정보>
# [마그네슘]1. 에너지 이용에 필요, 2. 신경과 근육 기능 유지에 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민B1]탄수화물과 에너지 대사에 필요
# [판토텐산]자방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B2]체내 에너지 생성에 필요
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [나이아신] 체내 에너지 생성에 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민B12]정상적인 엽산 대사에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [망간]1. 뼈 형성에 필요, 2. 에너지 이용에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [구리]1. 철의 운반과 이용에 필요, 2. 유해산소로부터 세포를 보호하는데 필요
# [엽산]1. 세포와 혈액생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2정을 물과 함꼐 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60정(60 g)
# **************************************************
# 제품특징
#
# 슈퍼우먼의 바쁜 일상, 하루 2정으로 활력에너지 충전
# 활력비타민 B군 강화
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 마그네슘 : 100 mg
# 비타민E : 30 mg α-TE
# 비타민C : 150 mg
# 비타민B1 : 50 mg
# 판토텐산 : 50 mg
# 비타민B6 : 50 mg
# 비타민B2 : 50 mg
# 셀렌 : 60 μg
# 철 : 7 mg
# 나이아신 : 14 mg NE
# 아연 : 8 mg
# 비오틴 : 50 μg
# 비타민A : 650 μg RE
# 비타민B12 : 50 μg
# 비타민D : 10 μg
# 망간 : 1 mg
# 구리 : 0.4 mg
# 엽산 : 400 μg
#
#
# 기능정보
#
# <기능정보>
# [마그네슘]1. 에너지 이용에 필요, 2. 신경과 근육 기능 유지에 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민B1]탄수화물과 에너지 대사에 필요
# [판토텐산]자방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B2]체내 에너지 생성에 필요
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [철]1. 체내 산소운반과 혈액생성에 필요, 2. 에너지 생성에 필요
# [나이아신] 체내 에너지 생성에 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비오틴]지방, 탄수화물, 단백질 대사와 에너지 생성에 필요
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민B12]정상적인 엽산 대사에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [망간]1. 뼈 형성에 필요, 2. 에너지 이용에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [구리]1. 철의 운반과 이용에 필요, 2. 유해산소로부터 세포를 보호하는데 필요
# [엽산]1. 세포와 혈액생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2정을 물과 함꼐 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60정(60 g)
# **************************************************
# 제품특징
#
# 마리골드꽃추출물, 비타민A · C · E, 아연, 구리
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(1캡슐) 당
# 루테인 : 20 mg
# 비타민A : 700 μg RE
# 비타민C : 30 mg
# 비타민E : 3.3 mg α-TE
# 아연 : 2.55 mg
# 구리 : 0.24 mg
# 땅콩, 대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [루테인]노화로 인해 감소될 수 있는 황반색소밀도를 유지하여 눈 건강에 도움을 줄 수 있음
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [구리]1. 철의 운반과 이용에 필요, 2. 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐 X 2개입(60 g)
# **************************************************
# 제품특징
#
# 루테인 + 비타민A, E
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(1캡슐) 당
# 비타민A : 495 μg RE
# 비타민E : 11 mg α-TE
# 루테인 : 20 mg
# ※대두, 땅콩 함유
#
#
# 기능정보
#
# <기능정보>
# [마리골드꽃추출물]노화로 인해 감소될 수 있는 황반색소밀도를 유지하여 눈 건강에 도움을 줌
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 300 mg X 30캡슐 X 2개입(18 g)
# **************************************************
# 제품특징
#
# 100억 유산균, 4중 코팅, 유산균특허기술
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 아연 : 8.5 mg
# 셀레늄 : 16.5 μg
#   ※우유, 대두, 쇠고기, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [셀레늄]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐(30 g)
# **************************************************
# 제품특징
#
# 체내 흡수가 용이한 3세대 rTG형 EPA 및 DHA 함유 유지(오메가3)
# 8중 멀티기능성
# 저온 초임계추출공법 사용
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 비타민D : 5 μg
# 비타민E : 5 mg α-TE
# EPA와 DHA의 합 : 1,000 mg
#   ※대두 함유
#
#
# 기능정보
#
# <기능정보>
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 기억력 개선에 도움을 줄 수 있음, 3. 건조한 눈을 개선하여 눈 건강에 도움을 줄 수 있음
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 630 mg X 60캡슐 X 2개입(75.6 g)
# **************************************************
# 제품특징
#
# 현대인의 마시는 스트레스 솔루션
# 홍경천추출물, 테아닌
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1병) 당
# 로사빈 : 4.8 mg
# L-테아닌 200 mg
#
#
# 기능정보
#
# <영양기능정보>
# 홍경천추출물 : 스트레스로 인한 피로개선에 도움을 줄 수 있음
# 테아닌 : 스트레스로 인한 긴장완화에 도움을 줄 수 있음
#
#
# 섭취방법
#
# 1일 1회, 1회 1병 섭취
#
#
# 포장단위
#
# 1병(100mL), 10박스
# **************************************************
# 제품특징
#
# 비타민A·E + 아연
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 비타민A : 700 μg RE
# 비타민E : 11 mg α-TE
# 아연 : 3.4 mg
# 루테인 : 20 mg
#   ※대두, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [루테인]노화로 인해 감소될 수 있는 황반색소밀도를 유지하여 눈 건강에 도움을 줌
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐 X 2개입(60 g)
# **************************************************
# 제품특징
#
# 1일 EPA+DHA 1,300 mg 섭취
# 정제어유 성분
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# EPA와 DHA의 합 : 1,300 mg
#   ※대두, 쇠고기, 고등어 함유
#
#
# 기능정보
#
# <기능정보>
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 기억력 개선에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,200 mg X 120캡슐(144 g)
# **************************************************
# 제품특징
#
# 필수 영양성분 비타민C
# 영국산 프리미엄 비타민C 원료
# 레몬맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 비타민C : 500 mg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포를 입안에서 녹여 섭취하십시오.
#
#
# 포장단위
#
# 2 g X 30포(60 g)
# **************************************************
# 제품특징
#
# 톡 터지는 상큼한 츄어블 캡슐
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 비타민D : 50 μg
# ※우유, 대두, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 280 mg X 90캡슐(25.2 g)
# **************************************************
# 제품특징
#
# 눈에 영양공급이 필요하신 분
# 노화로 인하여 눈이 침침하신 분
# 컴퓨터, 휴대폰 사용이 잦은 현대인
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 비타민C : 250 mg
# 비타민E : 134.2 mg α-TE
# 구리 : 1 mg
# 아연 : 12 mg
# 루테인 : 10.8 mg
# 지아잔틴 : 2.7 mg
# 베타카로틴 : 7 mg
# EPA와 DHA의 합 : 640 mg
#   ※대두, 쇠고기, 고등어 함유
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [구리]1. 철의 운반과 이용에 필요, 2. 유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [루테인지아잔틴복합추출물20%]노화로 인해 감소될 수 있는 황반색소밀도를 유지시켜 주어 눈 건강에 도움을 줌
# [베타카로틴]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [EPA 및 DHA 함유 유지]1. 혈중 중성지질 개선·혈행 개선에 도움을 줄 수 있음, 2. 건조한 눈을 개선하여 눈 건강에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 60캡슐 X 2개입(120 g)
# **************************************************
# 제품특징
#
# 코엔자임Q10 + 비타민B6 + 비타민E
# 활력에너지, 항산화기능, 혈압건강
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 코엔자임Q10 : 100 mg
# 비타민B6 : 1.5 mg
# 비타민E : 5.5 mg α-TE
#   ※대두, 돼지고기 함유
#
#
# 기능정보
#
# <기능정보>
# [코엔자임Q10]항산화·높은 혈압 감소에 도움을 줄 수 있음
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 충분한 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 60캡슐 X 2개입(60 g)
# **************************************************
# 제품특징
#
# 우리가족을 위한 5종 맞춤 프로바이오틱스
# 하루 한 캡슐 보장균수 100억 2개월 실속 포장 유산균
#
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 아연 : 12 mg
# 셀레늄 : 16.5 μg
#   ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [셀레늄]유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg x 60캡슐(30 g)
# **************************************************
# 영상
#
#
#
# 제품특징
#
# 10종의 맞춤 프로바이오틱스
# 하루 한 캡슐 투입균수 900억 보장균수 100억 프리미엄 유산균
# 100% 국내산 유산균
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 아연 : 4 mg
#   ※대두, 우유 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500 mg X 30 캡슐(15 g)
# **************************************************
# 영상
#
#
#
# 제품특징
#
# 우리아이 성장을 위한 첫! 유산균
# 7종의 맞춤 프로바이오틱스
# 우리아이 성장발달에 필수적인 영양성분의 과학적인 배합 - 아연, 철, 비타민D, 비타민B1, B2, 나이아신, 비타민B6, 비타민B12
#
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(1포) 당
# 프로바이오틱스 수 : 1,000,000,000 CFU
# 아연 : 3 mg
# 철 : 6 mg
# 비타민D : 5 μg
# 비타민B1 : 0.5 mg
# 비타민B2 : 0.5 mg
# 나이아신 : 6 mgNE
# 비타민B6 : 0.6 mg
# 비타민B12 : 0.9 μg
# 우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [철]1. 체내 산소운반과 혈액생성에 필요, 2. 에너지 생성에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 골다공증발생 위험 감소에 도움을 줌
# [비타민B1] 탄수화물과 에너지 대사에 필요
# [비타민B2, 나이아신] 체내 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B12] 정상적인 엽산 대사에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 섭취하십시오.
#
#
# 포장단위
#
# 1,500 mg X 30포(45 g)
# **************************************************
# 제품특징
#
# 투입균수 1500억 보장균수 100억
# 비피더스균을 강화한 장건강 유산균
# ※약국 내 건강기능식품 코너 전용 제품입니다.
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량: 2캡슐(900 mg)
# 1일 섭취량 당 함량:
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 아연 : 8.5 mg
# 비타민D : 10 μg
#   우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음, 3. 장건강에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# (450 mg x 60캡슐) x 2개입 (54 g)
# **************************************************
# 영상
#
#
#
# 제품특징
#
# 4중 멀티기능성
# 프로바이오틱스+비타민D+셀렌+아연
# 12종 생유산균
# 맛있는 바나나맛
#
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(1포) 당
# 프로바이오틱스 수 : 3,000,000,000 CFU
# 비타민D : 3 mg
# 셀렌 : 16.5 mg
# 아연 : 2.55 mg
# ※우유, 대두, 밀 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 섭취하십시오.
#
#
# 포장단위
#
# 2 g X 30포 (60 g)
# **************************************************
# 영상
#
#
#
# 제품특징
#
# 장까지 살아가는 4중 코팅 특허 기술
# 100억 프로바이오틱스
# 프로&프리바이오틱스
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 자일로올리고당 : 700 mg
#   ※대두, 우유 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [자일로올리고당 분말]1. 장내 유익균 증식, 2. 유해균 억제, 3. 배변활동에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 (물과 함께) 섭취하십시오.
#
#
# 포장단위
#
# (2,000 mg X 30포) X 2개입(120 g)
# **************************************************
# 영상
#
#
#
# 제품특징
#
# 하/루/한/포로 지키는 우리가족 장 건강 밸런스
# 맛있는 사과맛, 바나나맛
# 엄선한 과일유래식이섬유(보조성분) 3종 함유
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량(1포) 당
# 프로바이오틱스 수 : 1,000,000,000 CFU
# ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스] 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 배변활동 원활에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 섭취하십시오.
#
#
# 포장단위
#
# 2 g X 90포 (180 g)
# **************************************************
# 제품특징
#
# 우리아이를 위한 7종 맞춤
# 맛있는 바나나맛 프로바이오틱스
# 하루 한 포 투입균수 450억, 보장균수 30억 프리미엄 유산균
# ※본 제품은 질명의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조 · 가공한 건강기능식품 입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 아연 : 4 mg
# ※ 우유, 대두, 밀 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [[비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 2 g x 30포 (60 g)
# **************************************************
# 제품특징
#
# 꼭꼭 씹어먹는 우리아이 프로바이오틱스
# 모유 유래 유산균
# 새콤달콤 딸기맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 1일 섭취량: 2정
# 1일 섭취량 당 함량:
# 프로바이오틱스 수 : 1,000,000,000 CFU
# 아연 : 5 mg
#   ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음, 3. 장건강에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1정을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1 g x 60정(60 g)
# **************************************************
# 제품특징
#
# 장편한 하루를 위한 장건강 프로젝트
# 지큐랩 장건강 프리바이오틱스로 내 몸 속 유익균을 높이세요!
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 프락토올리고당: 3,000 mg
# 아연: 2.55 mg
# ※우유, 대두, 밀 함유
#
#
# 기능정보
#
# <기능정보>
# [프락토올리고당] 장내 유익균 증식 및 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포(4 g)를 섭취하십시오.
#
#
# 포장단위
#
# 4 g x 30포 (120 g)
# **************************************************
# 제품특징
#
# 우리아이를 위한 7종 맞춤 프로바이오틱스
# 모유 유래 유산균 함유
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 프로바이오틱스 수 : 5,000,000,000 CFU
# 아연 : 5 mg
# 비타민D : 5 μg
#
# ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음, 3. 장건강에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 (물과 함께) 섭취하십시오.
#
#
# 포장단위
#
# 2 g x 30포 (60 g)
# **************************************************
# 제품특징
#
# 식물 유래 프리바이오틱스, 자일로올리고당을 더한 장건강 유산균
# ※약국 내 건강기능식품 코너 전용 제품입니다.
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 프로바이오틱스 수 : 10,000,000,000 CFU
# 자일로올리고당 : 700 mg
# 비타민D : 3 μg
# 셀렌 : 16.5 μg
# 아연 : 2.55 mg
# ※우유, 대두, 밀 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음, 3. 장건강에 도움을 줄 수 있음
# [자일로올리고당]1. 장내 유익균 증식, 2. 유해균 억제, 3. 배변활동에 도움을 줄 수 있음
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포를 털어서 섭취하십시오.
#
#
# 포장단위
#
# (2.5 g x 10포) x 6개입 (150 g)
# **************************************************
# 제품특징
#
# 유산균이 만드는 이로운 대사산물, 포스트바이오틱스
# 틴달공법으로 4,000% 농축 108억셀 포스트바이오틱스
# 유산균의 먹이 프리바이오틱스, 프락토올리고당 3,200 mg 함유
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 열처리배양균체 수: 1.08 x 1010 cells
# Lactic acid: 48.8 mg
# 프락토올리고당: 3.2 g
# ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [Lactobacillus rhamnosus IDCC3201 열처리배양건조물] 면역과민반응에 의한 피부상태 개선에 도움을 줄 수 있음
# [프락토올리고당] 장내 유익균 증식 및 배변활동 원활에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포를 섭취하십시오.
#
#
# 포장단위
#
# 5 g x 30포 (150 g)
# **************************************************
# 제품특징
#
# 3중 멀티 기능성, 장건강 + 정상적인 면역기능 + 항산화 건강
#   ※약국 내 건강기능식품 코너 전용 제품 입니다.
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 프락토올리고당: 3,000 mg
# 아연: 8.5 mg
# 셀레늄: 55 μg
# ※우유, 대두, 밀 함유
#
#
# 기능정보
#
# <기능정보>
# [프락토올리고당] 장내 유익균 증식 및 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [셀레늄] 유해산소로부터 세포를 보호하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포(4 g)를 섭취하십시오.
#
#
# 포장단위
#
# 4 g x 30포 (120 g)
# **************************************************
# 제품특징
#
# 코엔자임Q10 100 mg, 비타민A·B1·B2·B6·B12·C·E·엽산, 셀렌
# 혈압건강, 눈건강, 항산화기능, 활력에너지
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1캡슐) 당
# 비타민B1 : 1.95 mg
# 비타민B12 : 2.4 μg
# 비타민B2 : 2 mg
# 비타민B6 : 2.05 mg
# 비타민C : 30 mg
# 비타민A : 700 μg RE
# 비타민E : 10 mg α-TE
# 셀렌 : 16.5 μg
# 엽산 : 400 μg
# 코엔자임Q10 : 100 mg
#   ※대두, 땅콩, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [코엔자임Q10]항산화·높은 혈압 감소에 도움을 줄 수 있음
# [비타민B1]탄수화물과 에너지 대사에 필요
# [비타민B12]정상적인 엽산 대사에 필요
# [비타민B2]체내 에너지 생성에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [비타민A]1. 어두운 곳에서 시각 적응을 위해 필요, 2. 피부와 점막을 형성하고 기능을 유지하는데 필요, 3. 상피세포의 성장과 발달에 필요
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [셀렌]유해산소로부터 세포를 보호하는데 필요
# [엽산]1. 세포와 혈액 생성에 필요, 2. 태아 신경관의 정상 발달에 필요, 3. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1캡슐을 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 700 mg X 60캡슐 X 2개입 (84 g)
# **************************************************
# 제품특징
#
# 매일매일 맛있는 아연+비타민D 영양젤리
# 엘더베리 & 스트로베리맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 아연 : 6 mg
# 비타민D : 5 μg
#
#
# 기능정보
#
# <기능정보>
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비타민D] 1. 칼슘과 인이 흡수되고 이용되는데  필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포(15 g)를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# (15 g x 20포) x 2박스 (600 g)
# **************************************************
# 제품특징
#
# 매일매일 맛있는 비타민&미네랄 영양젤리
# 새콤한 사과맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 비타민E : 5 mg α-TE
# 나이아신 : 15 mg NE
# 아연 : 4.7 mg
# 비타민B6 : 1.5 mg
# 비타민B1 : 1.2 mg
#
#
# 기능정보
#
# <기능정보>
# [비타민E]유해산소로부터 세포를 보호하는데 필요
# [나이아신] 체내 에너지 생성에 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [비타민B6]1. 단백질 및 아미노산 이용에 필요, 2. 혈액의 호모시스테인 수준을 정상으로 유지하는데 필요
# [비타민B1]탄수화물과 에너지 대사에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포(15 g)를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 15 g X 30포(450 g)
# **************************************************
# 제품특징
#
# 맛있게 씹어먹는 아연·비타민C
# 새콤달콤 딸기맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료>
# 비타민C : 50 mg
# 아연 : 8 mg
#
#
# 기능정보
#
# <기능정보>
# [비타민C]1. 결합조직 형성과 기능유지에 필요, 2. 철의 흡수에 필요, 3. 유해산소로부터 세포를 보호하는데 필요
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1정을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,500 mg X 30정(45 g)
# **************************************************
# 제품특징
#
# 칼슘 + 비타민D + 아연
# 3중 복합 기능성
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 칼슘 : 210 mg
# 비타민D : 10 μg
# 아연 : 3 mg
#   ※우유, 대두 함유
#
#
# 기능정보
#
# <기능정보>
# [칼슘]1. 뼈와 치아 형성에 필요, 2. 신경과 근육 기능 유지에 필요, 3. 정상적인 혈액응고에 필요, 4. 골다공증발생 위험 감소에 도움을 줌
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1정을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,500 mg X 60정 X 2개입 (180 g)
# **************************************************
# 제품특징
#
# 면역력 쑥쑥!!
# 우리 아이가 잘 먹은 맛있는 홍삼
# 홍삼, 아연, 나이아신
# 오렌지맛
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2포) 당
# 아연 : 5 mg
# 나이아신 : 8.3 mg NE
# 진세노사이드 Rg1, Rb1 및 Rg3의 합 : 3 mg
#
#
# 기능정보
#
# <기능정보>
# [홍삼]면역력 증진·피로개선·혈소판 응집억제를 통한 혈액흐름·기억력 개선·항산화에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
# [나이아신]체내 에너지 생성에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1포를 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 15 g X 20포(300 g)
# **************************************************
# 제품특징
#
# 칼슘 + 비타민D + 아연
# 성장기 필수 영양칼슘
# 맛있게 씹어먹는 우유맛 츄어블정
# 휴대가 간편한 개별 포장
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(4정) 당
# 칼슘 : 210 mg
# 비타민D : 10 μg
# 아연 : 3 mg
#   ※우유 함유
#
#
# 기능정보
#
# <기능정보>
# [칼슘]1. 뼈와 치아 형성에 필요, 2. 신경과 근육 기능 유지에 필요, 3. 정상적인 혈액응고에 필요, 4. 골다공증발생 위험 감소에 도움을 줌
# [비타민D]1. 칼슘과 인이 흡수되고 이용되는데 필요, 2. 뼈의 형성과 유지에 필요, 3. 골다공증발생 위험 감소에 도움을 줌
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 2정을 씹거나 녹여서 섭취하십시오.
#
#
# 포장단위
#
# 1.5 mg X 120정(180 g)
# **************************************************
# 제품특징
#
# 4중 코팅
# 100억 유산균
# 유산균 특허 기술
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2캡슐) 당
# 프로바이오틱스 수 : 10,000,000,000 CFU
#   ※우유, 대두, 돼지고기, 쇠고기 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 2캡슐씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 500mg x 120캡슐(60g)
# **************************************************
# 제품특징
#
# 유산균에 비피더스균을 강화한 '4중코팅'
# 어린이 프로바이오틱스(50억 프로바이오틱스)
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(1포) 당
# 프로바이오틱스 수 : 5,000,000,000 CFU
# 아연 : 5 mg
#   ※대두, 우유 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 1회, 1회 1포씩 물과 함께 섭취하십시오.
#
#
# 포장단위
#
# 2.5 g X 30포 X2개입(150 g)
# **************************************************
# 제품특징
#
# 씹어먹는 '4중코팅' 어린이 프로바이오틱스
# 정상적인 면역기능·세포분열에 필요한 아연 함유
# ※본 제품은 질병의 예방 및 치료를 위한 의약품이 아니며 인체에 유용한 기능성을 가진 원료나 성분을 사용하여 제조·가공한 건강기능식품입니다.
#
#
# 성분/함량
#
# <기능성원료 및 함량>
# 1일 섭취량(2정) 당
# 프로바이오틱스 수 : 500,000,000 CFU
# 아연 : 5 mg
#   ※대두, 우유 함유
#
#
# 기능정보
#
# <기능정보>
# [프로바이오틱스]1. 유산균 증식 및 유해균 억제에 도움을 줄 수 있음, 2. 배변활동 원활에 도움을 줄 수 있음
# [아연]1. 정상적인 면역기능에 필요, 2. 정상적인 세포분열에 필요
#
#
# 섭취방법
#
# <섭취량 및 섭취방법>
# 1일 2회, 1회 1정을 씹어서 섭취하십시오.
#
#
# 포장단위
#
# 1,000 mg X 120정(120 g)
# **************************************************
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-202-bf73e9c62ca7> in <module>
#       6
#       7     for idx in range(0,9) :
# ----> 8         tags[idx].click()
#       9         prdName = driver.find_element_by_class_name('detailCnt2')
#      10         print(prdName.text)
#
# IndexError: list index out of range

# %%
for page in range(1,10) : 
    url = 'https://www.ildong.com/kor/product/list.id?page='+str(page)+'&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0'
# Out:
# https://www.ildong.com/kor/product/list.id?page=1&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=2&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=3&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=4&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=5&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=6&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=7&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=8&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
# https://www.ildong.com/kor/product/list.id?page=9&halt=&prdDisease=&prdCategory=5&searchVal=&searchOption=0
