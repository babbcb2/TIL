# %%
from konlpy.tag import Hannanum
hannanum = Hannanum()

# %%
# from eunjeon import Mecab
# from OCR import main

import time

# text = main()

# %%
text01 = '"자세히 들여다ø봐.어서,내가 있는 곳에 서." 해리가 옆으로 비켜서고 론이 거울 앞에 섰다.그러나 론은 해리의 가족을 볼 수 없었다. 그는 그저 페이즐리직(가는 곡선 무늬를 짜 넣은 부드러운 모직물:옮긴이)잠옷을 입고 있는 자신 의 모습만을 볼 뿐이었다. 론은_거울에 비친 자신의 상을 뚫어질 듯 바라보았다. "날 봐!" 그가 말했다 "네 주위에 서 있는 가족이 모두 보이니?" "아니-난 혼자야ø그런데 난 달리늙어 보여ø 그리고 내가 학생 회장이야!" "뭐라구?" "내가ø내가 빌이 달고 다니곤 했던 배지를 달고 있어ø 그리고 내가 기숙사_우승컵과 퀴디치 우승컵을 들고 있어ø 난 또 퀴디치 주장이야!" 론은 이 놀라운 광경에서 고개를 돌려 홍분한 얼굴로 해리 를 보았다. "이 거울이 미래를 보여준다고 생각지 않니?" "어떻게 그럴 수 있어?.우리 가족은 모두 죽었어ø나 한번 더 보자 " "넌 어젯밤에 혼자서 해봤잖아,나 조금만 더 볼게." "넌ø그저_퀴디치_우승컵을들고 있을 뿐이잖아, 그게 뭐 그 리ø대단하니? 난 엄마, 아빠가 보고 싶단 말야." "밀지 마"' 

text02 = '"그렇다면 이렇게 말다툼만 할 게 아니라 우리 대결을 한 번 하는 게 어때?"'

# %%
print('<hannanum>')

print('morphs\n',hannanum.morphs(text01))
print("*" * 50)

print('nouns\n', hannanum.nouns(text01))
print("*" * 50)

# print('phrases\n', hannanum.phrases(text01))
# print("*" *  50)
print('pos\n', hannanum.pos(text01))

# %%
from konlpy.tag import Okt
okt = Okt()

# %%
print('<okt>')
print('morphs\n',okt.morphs(text01))
print("*" * 50)
print('nouns\n', okt.nouns(text01))
print("*" * 50)
print('phrases\n', okt.phrases(text01))
print("*" * 50)
print('pos\n', okt.pos(text01))
# Out:
# <okt>
# morphs
#  ['바람', '은', '으', '시', '대면', '서', '말', '했습니다', '.', '해님', '은', '얼굴', '가득', '웃음', '을', '띠', '며', '바람', '에게', '말', '했습니다', '.', '"', '이', '세상', '에는', '네', '뜻대로', '되지', '않는', '것', '도', '있어', '.', '밝은', '빛과', '따뜻한', '열', '을', '주는', '것', '은', '바람', '이', '아니라', '이', '해님', '이란', '말', '이야', '."', '해님', '과', '바람', '은', '이렇게', '옥신각신', '서로', '의', '자랑', '을', '늘어놓다가', '마침내', '는', '말다툼', '으로까지', '번지', '게', '되었습니다', '.', '자존심', '이', '상한', '바람', '이', '급한', '성질', '을', '참지', '못', '하고', '해님', '에게', '말', '했습니다', '.', '"', '그렇다면', '이렇게', '말다툼', '만', '할', '게', '아니라', '우리', '대결', '을', '한', '번', '하는', '게', '어때', '?"']
# **************************************************
# nouns
#  ['바람', '대면', '말', '해님', '얼굴', '가득', '웃음', '띠', '바람', '말', '이', '세상', '네', '것', '빛과', '열', '것', '바람', '이', '해님', '말', '해님', '바람', '옥신각신', '서로', '자랑', '마침내', '말다툼', '번지', '자존심', '상한', '바람', '성질', '못', '해님', '말', '말다툼', '게', '우리', '대결', '번', '게']
# **************************************************
# phrases
#  ['바람', '시대면', '해님', '얼굴', '얼굴 가득', '얼굴 가득 웃음', '이 세상', '빛과', '빛과 따뜻한 열', '이 해님', '해님과 바람', '옥신각신', '옥신각신 서로', '옥신각신 서로의 자랑', '마침내', '말다툼', '번지', '자존심', '상한', '상한 바람', '급한 성질', '우리', '우리 대결', '번 하는 게', '가득', '웃음', '세상', '서로', '자랑', '성질', '대결']
# **************************************************
# pos
#  [('바람', 'Noun'), ('은', 'Josa'), ('으', 'Adverb'), ('시', 'Modifier'), ('대면', 'Noun'), ('서', 'Josa'), ('말', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('해님', 'Noun'), ('은', 'Josa'), ('얼굴', 'Noun'), ('가득', 'Noun'), ('웃음', 'Noun'), ('을', 'Josa'), ('띠', 'Noun'), ('며', 'Josa'), ('바람', 'Noun'), ('에게', 'Josa'), ('말', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('"', 'Punctuation'), ('이', 'Noun'), ('세상', 'Noun'), ('에는', 'Josa'), ('네', 'Noun'), ('뜻대로', 'Adverb'), ('되지', 'Verb'), ('않는', 'Verb'), ('것', 'Noun'), ('도', 'Josa'), ('있어', 'Adjective'), ('.', 'Punctuation'), ('밝은', 'Verb'), ('빛과', 'Noun'), ('따뜻한', 'Adjective'), ('열', 'Noun'), ('을', 'Josa'), ('주는', 'Verb'), ('것', 'Noun'), ('은', 'Josa'), ('바람', 'Noun'), ('이', 'Josa'), ('아니라', 'Adjective'), ('이', 'Noun'), ('해님', 'Noun'), ('이란', 'Josa'), ('말', 'Noun'), ('이야', 'Josa'), ('."', 'Punctuation'), ('해님', 'Noun'), ('과', 'Josa'), ('바람', 'Noun'), ('은', 'Josa'), ('이렇게', 'Adverb'), ('옥신각신', 'Noun'), ('서로', 'Noun'), ('의', 'Josa'), ('자랑', 'Noun'), ('을', 'Josa'), ('늘어놓다가', 'Verb'), ('마침내', 'Noun'), ('는', 'Josa'), ('말다툼', 'Noun'), ('으로까지', 'Josa'), ('번지', 'Noun'), ('게', 'Josa'), ('되었습니다', 'Verb'), ('.', 'Punctuation'), ('자존심', 'Noun'), ('이', 'Josa'), ('상한', 'Noun'), ('바람', 'Noun'), ('이', 'Josa'), ('급한', 'Adjective'), ('성질', 'Noun'), ('을', 'Josa'), ('참지', 'Verb'), ('못', 'Noun'), ('하고', 'Josa'), ('해님', 'Noun'), ('에게', 'Josa'), ('말', 'Noun'), ('했습니다', 'Verb'), ('.', 'Punctuation'), ('"', 'Punctuation'), ('그렇다면', 'Adjective'), ('이렇게', 'Adverb'), ('말다툼', 'Noun'), ('만', 'Josa'), ('할', 'Verb'), ('게', 'Noun'), ('아니라', 'Adjective'), ('우리', 'Noun'), ('대결', 'Noun'), ('을', 'Josa'), ('한', 'Verb'), ('번', 'Noun'), ('하는', 'Verb'), ('게', 'Noun'), ('어때', 'Adjective'), ('?"', 'Punctuation')]

# %%
from konlpy.tag import Komoran
komoran = Komoran()

# %%
print('<komoran>')
print('morphs\n',komoran.morphs(text01))
print("*" * 50)
print('nouns\n', komoran.nouns(text01))
# print("*" * 50)
# print('phrases\n', komoran.phrases(text01))
print("*" * 50)
print('pos\n', komoran.pos(text01))
# Out:
# <komoran>
# morphs
#  ['바람', '은', '으시대', '면서', '말', '하', '았', '습니다', '.', '해', '님', '은', '얼굴', '가득', '웃음', '을', '띠', '며', '바람', '에게', '말', '하', '았', '습니다', '.', '"', '이', '세상', '에', '는', '네', '뜻대로', '되', '지', '않', '는', '것', '도', '있', '어', '.', '밝', '은', '빛', '과', '따뜻', '하', 'ㄴ', '열', '을', '주', '는', '것', '은', '바람', '이', '아니', '라', '이', '해', '님', '이란', '말', '이', '야', '.', '"', '해', '님', '과', '바람', '은', '이렇', '게', '옥신각신', '서로', '의', '자랑', '을', '늘어놓', '다가', '마침내', '는', '말다툼', '으로', '까지', '번지', '게', '되', '었', '습니다', '.', '자존심', '이', '상하', 'ㄴ', '바람', '이', '급하', 'ㄴ', '성질', '을', '참', '지', '못하', '고', '해', '님', '에게', '말', '하', '았', '습니다', '.', '"', '그렇', '다면', '이렇', '게', '말다툼', '만', '하', 'ㄹ', '게', '아니', '라', '우리', '대결', '을', '한', '번', '하', '는', '게', '어떻', '어', '?', '"']
# **************************************************
# nouns
#  ['바람', '말', '해', '얼굴', '웃음', '바람', '말', '세상', '것', '빛', '열', '것', '바람', '해', '말', '해', '바람', '서로', '자랑', '말다툼', '자존심', '바람', '성질', '해', '말', '말다툼', '게', '대결', '번', '게']
# **************************************************
# pos
#  [('바람', 'NNG'), ('은', 'JX'), ('으시대', 'VV'), ('면서', 'EC'), ('말', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('습니다', 'EF'), ('.', 'SF'), ('해', 'NNG'), ('님', 'XSN'), ('은', 'JX'), ('얼굴', 'NNG'), ('가득', 'MAG'), ('웃음', 'NNG'), ('을', 'JKO'), ('띠', 'VV'), ('며', 'EC'), ('바람', 'NNG'), ('에게', 'JKB'), ('말', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('습니다', 'EF'), ('.', 'SF'), ('"', 'SS'), ('이', 'MM'), ('세상', 'NNG'), ('에', 'JKB'), ('는', 'JX'), ('네', 'MM'), ('뜻대로', 'MAG'), ('되', 'VV'), ('지', 'EC'), ('않', 'VX'), ('는', 'ETM'), ('것', 'NNB'), ('도', 'JX'), ('있', 'VX'), ('어', 'EF'), ('.', 'SF'), ('밝', 'VA'), ('은', 'ETM'), ('빛', 'NNG'), ('과', 'JC'), ('따뜻', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETM'), ('열', 'NNG'), ('을', 'JKO'), ('주', 'VX'), ('는', 'ETM'), ('것', 'NNB'), ('은', 'JX'), ('바람', 'NNG'), ('이', 'JKS'), ('아니', 'VCN'), ('라', 'EC'), ('이', 'MM'), ('해', 'NNG'), ('님', 'XSN'), ('이란', 'JX'), ('말', 'NNG'), ('이', 'VCP'), ('야', 'EF'), ('.', 'SF'), ('"', 'SS'), ('해', 'NNG'), ('님', 'XSN'), ('과', 'JC'), ('바람', 'NNG'), ('은', 'JX'), ('이렇', 'VA'), ('게', 'EC'), ('옥신각신', 'MAG'), ('서로', 'NNG'), ('의', 'JKG'), ('자랑', 'NNG'), ('을', 'JKO'), ('늘어놓', 'VV'), ('다가', 'EC'), ('마침내', 'MAG'), ('는', 'JX'), ('말다툼', 'NNG'), ('으로', 'JKB'), ('까지', 'JX'), ('번지', 'VV'), ('게', 'EC'), ('되', 'VV'), ('었', 'EP'), ('습니다', 'EF'), ('.', 'SF'), ('자존심', 'NNP'), ('이', 'JKS'), ('상하', 'VV'), ('ㄴ', 'ETM'), ('바람', 'NNG'), ('이', 'JKS'), ('급하', 'VA'), ('ㄴ', 'ETM'), ('성질', 'NNG'), ('을', 'JKO'), ('참', 'VV'), ('지', 'EC'), ('못하', 'VX'), ('고', 'EC'), ('해', 'NNG'), ('님', 'XSN'), ('에게', 'JKB'), ('말', 'NNG'), ('하', 'XSV'), ('았', 'EP'), ('습니다', 'EF'), ('.', 'SF'), ('"', 'SS'), ('그렇', 'VA'), ('다면', 'EC'), ('이렇', 'VA'), ('게', 'EC'), ('말다툼', 'NNG'), ('만', 'JX'), ('하', 'VV'), ('ㄹ', 'ETM'), ('게', 'NNG'), ('아니', 'VCN'), ('라', 'EC'), ('우리', 'NP'), ('대결', 'NNG'), ('을', 'JKO'), ('한', 'MM'), ('번', 'NNB'), ('하', 'VV'), ('는', 'ETM'), ('게', 'NNG'), ('어떻', 'VA'), ('어', 'EF'), ('?', 'SF'), ('"', 'SS')]

# %%
from konlpy.tag import Kkma
kkma = Kkma()

# %%
print('<kkma>')
print('morphs\n',kkma.morphs(text01))
print("*" * 50)
print('nouns\n', kkma.nouns(text01))
# print("*" * 50)
# print('phrases\n', komoran.phrases(text01))
print("*" * 50)
print('pos\n', kkma.pos(text01))
# Out:
# <kkma>
# morphs
#  ['바람', '은', '으시대', '면서', '말하', '었', '습니다', '.', '해님', '은', '얼굴', '가득', '웃음', '을', '띠', '며', '바람', '에게', '말하', '었', '습니다', '.', '"', '이', '세상', '에', '는', '네', '뜻', '대로', '되', '지', '않', '는', '것', '도', '있', '어', '.', '밝', '은', '빛', '과', '따뜻', '하', 'ㄴ', '열', '을', '주', '는', '것', '은', '바람', '이', '아니', '라', '이', '해님', '이', '란', '말', '이', '야', '.', '"', '해님', '과', '바람', '은', '이렇', '게', '옥신각신', '서로', '의', '자랑', '을', '늘어놓', '다가', '마침내', '는', '말다툼', '으로', '까지', '번지', '게', '되', '었', '습니다', '.', '자존심', '이', '상하', 'ㄴ', '바람', '이', '급하', 'ㄴ', '성질', '을', '참', '지', '못하', '고', '해님', '에게', '말하', '었', '습니다', '.', '"', '그렇', '다면', '이렇', '게', '말다툼', '만', '하', 'ㄹ', '것', '이', '아니', '라', '우리', '대결', '을', '한', '번', '하', '는', '것', '이', '어', '어', '때', '?', '"']
# **************************************************
# nouns
#  ['바람', '해님', '얼굴', '웃음', '세상', '뜻', '빛', '열', '말', '서로', '자랑', '말다툼', '자존심', '성질', '우리', '대결', '번', '때']
# **************************************************
# pos
#  [('바람', 'NNG'), ('은', 'JX'), ('으시대', 'VV'), ('면서', 'ECE'), ('말하', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('해님', 'NNG'), ('은', 'JX'), ('얼굴', 'NNG'), ('가득', 'MAG'), ('웃음', 'NNG'), ('을', 'JKO'), ('띠', 'VV'), ('며', 'ECE'), ('바람', 'NNG'), ('에게', 'JKM'), ('말하', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('"', 'SS'), ('이', 'MDT'), ('세상', 'NNG'), ('에', 'JKM'), ('는', 'JX'), ('네', 'MDN'), ('뜻', 'NNG'), ('대로', 'JX'), ('되', 'VV'), ('지', 'ECD'), ('않', 'VXV'), ('는', 'ETD'), ('것', 'NNB'), ('도', 'JX'), ('있', 'VV'), ('어', 'ECD'), ('.', 'SF'), ('밝', 'VA'), ('은', 'ETD'), ('빛', 'NNG'), ('과', 'JKM'), ('따뜻', 'XR'), ('하', 'XSA'), ('ㄴ', 'ETD'), ('열', 'NNG'), ('을', 'JKO'), ('주', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('은', 'JX'), ('바람', 'NNG'), ('이', 'JKC'), ('아니', 'VCN'), ('라', 'ECD'), ('이', 'MDT'), ('해님', 'NNG'), ('이', 'VCP'), ('란', 'ETD'), ('말', 'NNG'), ('이', 'VCP'), ('야', 'EFN'), ('.', 'SF'), ('"', 'SS'), ('해님', 'NNG'), ('과', 'JKM'), ('바람', 'NNG'), ('은', 'JX'), ('이렇', 'VA'), ('게', 'ECD'), ('옥신각신', 'MAG'), ('서로', 'NNG'), ('의', 'JKG'), ('자랑', 'NNG'), ('을', 'JKO'), ('늘어놓', 'VV'), ('다가', 'ECD'), ('마침내', 'MAG'), ('는', 'JX'), ('말다툼', 'NNG'), ('으로', 'JKM'), ('까지', 'JX'), ('번지', 'VV'), ('게', 'ECD'), ('되', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('자존심', 'NNG'), ('이', 'JKS'), ('상하', 'VV'), ('ㄴ', 'ETD'), ('바람', 'NNG'), ('이', 'JKS'), ('급하', 'VA'), ('ㄴ', 'ETD'), ('성질', 'NNG'), ('을', 'JKO'), ('참', 'VV'), ('지', 'ECD'), ('못하', 'VX'), ('고', 'ECE'), ('해님', 'NNG'), ('에게', 'JKM'), ('말하', 'VV'), ('었', 'EPT'), ('습니다', 'EFN'), ('.', 'SF'), ('"', 'SS'), ('그렇', 'VA'), ('다면', 'ECE'), ('이렇', 'VA'), ('게', 'ECD'), ('말다툼', 'NNG'), ('만', 'JX'), ('하', 'VV'), ('ㄹ', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('아니', 'VCN'), ('라', 'ECD'), ('우리', 'NNG'), ('대결', 'NNG'), ('을', 'JKO'), ('한', 'MDN'), ('번', 'NNB'), ('하', 'VV'), ('는', 'ETD'), ('것', 'NNB'), ('이', 'JKS'), ('어', 'VV'), ('어', 'ECS'), ('때', 'NNG'), ('?', 'SF'), ('"', 'SS')]

# %%
print(hannanum.morphs('세상에는 자기 입장을 정당화하기 위해 다른 사람을 습관적으로 비판하는 사람도 있어요.'))
